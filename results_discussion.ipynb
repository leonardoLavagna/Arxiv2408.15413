# %% [markdown]
# # Results_discussion
#
# **Remark.** The result discussion depends on the seeded executions of the algorithms and associated averages. In this notebook we consider seeds 121,122,123 whose corresponding results are stored in the `results` directory.

# %% [markdown]
# ## Set up

# %%
import os
import pickle
import numpy as np
import matplotlib.pyplot as plt

# %%
results_path = "results"

# %% [markdown]
# ## Data loading

# %%
names = []
for filename in os.listdir(results_path):
    if os.path.isfile(os.path.join(results_path, filename)):
        names.append(filename)

# %%
names = [name for name in names if "qaoa" in name]

# %%
AR_dict = {}
for name in names:
    with open("results/" + name, 'rb') as file:
        ar = pickle.load(file)
    AR_dict[name] = ar[2]

# %%
names_p1 = [name for name in names if "p_1" in name]

names_p1_vanilla = [name for name in names_p1 if "vanilla" in name]
names_p1_vanilla = sorted(names_p1_vanilla, key=lambda x: int(x.split("_")[3]))

names_p1_extended_1 = [name for name in names_p1 if "extended_1" in name]
names_p1_extended_1 = sorted(names_p1_extended_1, key=lambda x: int(x.split("_")[4]))

names_p1_extended_2 = [name for name in names_p1 if "extended_2" in name]
names_p1_extended_2 = sorted(names_p1_extended_2, key=lambda x: int(x.split("_")[4]))

names_p1_extended_3 = [name for name in names_p1 if "extended_3" in name]
names_p1_extended_3 = sorted(names_p1_extended_3, key=lambda x: int(x.split("_")[4]))

names_p1_reduced = [name for name in names_p1 if "reduced" in name]
names_p1_reduced = sorted(names_p1_reduced, key=lambda x: int(x.split("_")[3]))

names_p1 = list(names_p1_vanilla) + list(names_p1_extended_1) + list(names_p1_extended_2) + list(names_p1_extended_3) + list(names_p1_reduced)

# %%
names_p2 = [name for name in names if "p_2" in name]

names_p2_vanilla = [name for name in names_p2 if "vanilla" in name]
names_p2_vanilla = sorted(names_p2_vanilla, key=lambda x: int(x.split("_")[3]))

names_p2_extended_1 = [name for name in names_p2 if "extended_1" in name]
names_p2_extended_1 = sorted(names_p2_extended_1, key=lambda x: int(x.split("_")[4]))

names_p2_extended_2 = [name for name in names_p2 if "extended_2" in name]
names_p2_extended_2 = sorted(names_p2_extended_2, key=lambda x: int(x.split("_")[4]))

names_p2_extended_3 = [name for name in names_p2 if "extended_3" in name]
names_p2_extended_3 = sorted(names_p2_extended_3, key=lambda x: int(x.split("_")[4]))

names_p2_reduced = [name for name in names_p2 if "reduced" in name]
names_p2_reduced = sorted(names_p2_reduced, key=lambda x: int(x.split("_")[3]))

names_p2 = list(names_p2_vanilla) + list(names_p2_extended_1) + list(names_p2_extended_2) + list(names_p2_extended_3) + list(names_p2_reduced)

# %%
names_p3 = [name for name in names if "p_3" in name]

names_p3_vanilla = [name for name in names_p3 if "vanilla" in name]
names_p3_vanilla = sorted(names_p3_vanilla, key=lambda x: int(x.split("_")[3]))

names_p3_extended_1 = [name for name in names_p3 if "extended_1" in name]
names_p3_extended_1 = sorted(names_p3_extended_1, key=lambda x: int(x.split("_")[4]))

names_p3_extended_2 = [name for name in names_p3 if "extended_2" in name]
names_p3_extended_2 = sorted(names_p3_extended_2, key=lambda x: int(x.split("_")[4]))

names_p3_extended_3 = [name for name in names_p3 if "extended_3" in name]
names_p3_extended_3 = sorted(names_p3_extended_3, key=lambda x: int(x.split("_")[4]))

names_p3_reduced = [name for name in names_p3 if "reduced" in name]
names_p3_reduced = sorted(names_p3_reduced, key=lambda x: int(x.split("_")[3]))

names_p3 = list(names_p3_vanilla) + list(names_p3_extended_1) + list(names_p3_extended_2) + list(names_p3_extended_3) + list(names_p3_reduced)

# %%
names_p4 = [name for name in names if "p_4" in name]

names_p4_vanilla = [name for name in names_p4 if "vanilla" in name]
names_p4_vanilla = sorted(names_p4_vanilla, key=lambda x: int(x.split("_")[3]))

names_p4_extended_1 = [name for name in names_p4 if "extended_1" in name]
names_p4_extended_1 = sorted(names_p4_extended_1, key=lambda x: int(x.split("_")[4]))

names_p4_extended_2 = [name for name in names_p4 if "extended_2" in name]
names_p4_extended_2 = sorted(names_p4_extended_2, key=lambda x: int(x.split("_")[4]))

names_p4_extended_3 = [name for name in names_p4 if "extended_3" in name]
names_p4_extended_3 = sorted(names_p4_extended_3, key=lambda x: int(x.split("_")[4]))

names_p4_reduced = [name for name in names_p4 if "reduced" in name]
names_p4_reduced = sorted(names_p4_reduced, key=lambda x: int(x.split("_")[3]))

names_p4 = list(names_p4_vanilla) + list(names_p4_extended_1) + list(names_p4_extended_2) + list(names_p4_extended_3) + list(names_p4_reduced)

# %%
names_p5 = [name for name in names if "p_5" in name]

names_p5_vanilla = [name for name in names_p5 if "vanilla" in name]
names_p5_vanilla = sorted(names_p5_vanilla, key=lambda x: int(x.split("_")[3]))

names_p5_extended_1 = [name for name in names_p5 if "extended_1" in name]
names_p5_extended_1 = sorted(names_p5_extended_1, key=lambda x: int(x.split("_")[4]))

names_p5_extended_2 = [name for name in names_p5 if "extended_2" in name]
names_p5_extended_2 = sorted(names_p5_extended_2, key=lambda x: int(x.split("_")[4]))

names_p5_extended_3 = [name for name in names_p5 if "extended_3" in name]
names_p5_extended_3 = sorted(names_p5_extended_3, key=lambda x: int(x.split("_")[4]))

names_p5_reduced = [name for name in names_p5 if "reduced" in name]
names_p5_reduced = sorted(names_p5_reduced, key=lambda x: int(x.split("_")[3]))

names_p5 = list(names_p5_vanilla) + list(names_p5_extended_1) + list(names_p5_extended_2) + list(names_p5_extended_3) + list(names_p5_reduced)

# %%
names_p6 = [name for name in names if "p_6" in name]

names_p6_vanilla = [name for name in names_p6 if "vanilla" in name]
names_p6_vanilla = sorted(names_p6_vanilla, key=lambda x: int(x.split("_")[3]))

names_p6_extended_1 = [name for name in names_p6 if "extended_1" in name]
names_p6_extended_1 = sorted(names_p6_extended_1, key=lambda x: int(x.split("_")[4]))

names_p6_extended_2 = [name for name in names_p6 if "extended_2" in name]
names_p6_extended_2 = sorted(names_p6_extended_2, key=lambda x: int(x.split("_")[4]))

names_p6_extended_3 = [name for name in names_p6 if "extended_3" in name]
names_p6_extended_3 = sorted(names_p6_extended_3, key=lambda x: int(x.split("_")[4]))

names_p6_reduced = [name for name in names_p6 if "reduced" in name]
names_p6_reduced = sorted(names_p6_reduced, key=lambda x: int(x.split("_")[3]))

names_p6 = list(names_p6_vanilla) + list(names_p6_extended_1) + list(names_p6_extended_2) + list(names_p6_extended_3) + list(names_p6_reduced)

# %%
names_p7 = [name for name in names if "p_7" in name]

names_p7_vanilla = [name for name in names_p7 if "vanilla" in name]
names_p7_vanilla = sorted(names_p7_vanilla, key=lambda x: int(x.split("_")[3]))

names_p7_extended_1 = [name for name in names_p7 if "extended_1" in name]
names_p7_extended_1 = sorted(names_p7_extended_1, key=lambda x: int(x.split("_")[4]))

names_p7_extended_2 = [name for name in names_p7 if "extended_2" in name]
names_p7_extended_2 = sorted(names_p7_extended_2, key=lambda x: int(x.split("_")[4]))

names_p7_extended_3 = [name for name in names_p7 if "extended_3" in name]
names_p7_extended_3 = sorted(names_p7_extended_3, key=lambda x: int(x.split("_")[4]))

names_p7_reduced = [name for name in names_p7 if "reduced" in name]
names_p7_reduced = sorted(names_p7_reduced, key=lambda x: int(x.split("_")[3]))

names_p7 = list(names_p7_vanilla) + list(names_p7_extended_1) + list(names_p7_extended_2) + list(names_p7_extended_3) + list(names_p7_reduced)

# %%
names_p8 = [name for name in names if "p_8" in name]

names_p8_vanilla = [name for name in names_p8 if "vanilla" in name]
names_p8_vanilla = sorted(names_p8_vanilla, key=lambda x: int(x.split("_")[3]))

names_p8_extended_1 = [name for name in names_p8 if "extended_1" in name]
names_p8_extended_1 = sorted(names_p8_extended_1, key=lambda x: int(x.split("_")[4]))

names_p8_extended_2 = [name for name in names_p8 if "extended_2" in name]
names_p8_extended_2 = sorted(names_p8_extended_2, key=lambda x: int(x.split("_")[4]))

names_p8_extended_3 = [name for name in names_p8 if "extended_3" in name]
names_p8_extended_3 = sorted(names_p8_extended_3, key=lambda x: int(x.split("_")[4]))

names_p8_reduced = [name for name in names_p8 if "reduced" in name]
names_p8_reduced = sorted(names_p8_reduced, key=lambda x: int(x.split("_")[3]))

names_p8 = list(names_p8_vanilla) + list(names_p8_extended_1) + list(names_p8_extended_2) + list(names_p8_extended_3) + list(names_p8_reduced)

# %% [markdown]
# ## Qaoa results Analysis

# %% [markdown]
# ### Complete graphs

# %% [markdown]
# #### aggregating results

# %%
results_p1 = []
for i in range(12):
        results_p1.append(AR_dict[names_p1[i]])
    
for i in range(48,60):
        results_p1.append(AR_dict[names_p1[i]])

for i in range(96,108):
        results_p1.append(AR_dict[names_p1[i]])

for i in range(144,156):
        results_p1.append(AR_dict[names_p1[i]])

for i in range(192,204):
        results_p1.append(AR_dict[names_p1[i]])

results_p1_complete = [(results_p1[i] + results_p1[i+1] + results_p1[i+2]) / 3 for i in range(0, len(results_p1), 3)]

# %%
results_p2 = []
for i in range(12):
        results_p2.append(AR_dict[names_p2[i]])
    
for i in range(48,60):
        results_p2.append(AR_dict[names_p2[i]])

for i in range(96,108):
        results_p2.append(AR_dict[names_p2[i]])

for i in range(144,156):
        results_p2.append(AR_dict[names_p2[i]])

for i in range(192,204):
        results_p2.append(AR_dict[names_p2[i]])

results_p2_complete = [(results_p2[i] + results_p2[i+1] + results_p2[i+2]) / 3 for i in range(0, len(results_p2), 3)]

# %%
results_p3 = []
for i in range(12):
        results_p3.append(AR_dict[names_p3[i]])
    
for i in range(48,60):
        results_p3.append(AR_dict[names_p3[i]])

for i in range(96,108):
        results_p3.append(AR_dict[names_p3[i]])

for i in range(144,156):
        results_p3.append(AR_dict[names_p3[i]])

for i in range(192,204):
        results_p3.append(AR_dict[names_p3[i]])

results_p3_complete = [(results_p3[i] + results_p3[i+1] + results_p3[i+2]) / 3 for i in range(0, len(results_p3), 3)]

# %%
results_p4 = []
for i in range(12):
        results_p4.append(AR_dict[names_p4[i]])
    
for i in range(48,60):
        results_p4.append(AR_dict[names_p4[i]])

for i in range(96,108):
        results_p4.append(AR_dict[names_p4[i]])

for i in range(144,156):
        results_p4.append(AR_dict[names_p4[i]])

for i in range(192,204):
        results_p4.append(AR_dict[names_p4[i]])

results_p4_complete = [(results_p4[i] + results_p4[i+1] + results_p4[i+2]) / 3 for i in range(0, len(results_p4), 3)]

# %%
results_p5 = []
for i in range(12):
        results_p5.append(AR_dict[names_p5[i]])
    
for i in range(48,60):
        results_p5.append(AR_dict[names_p5[i]])

for i in range(96,108):
        results_p5.append(AR_dict[names_p5[i]])

for i in range(144,156):
        results_p5.append(AR_dict[names_p5[i]])

for i in range(192,204):
        results_p5.append(AR_dict[names_p5[i]])

results_p5_complete = [(results_p5[i] + results_p5[i+1] + results_p5[i+2]) / 3 for i in range(0, len(results_p5), 3)]

# %%
results_p6 = []
for i in range(12):
        results_p6.append(AR_dict[names_p6[i]])
    
for i in range(48,60):
        results_p6.append(AR_dict[names_p6[i]])

for i in range(96,108):
        results_p6.append(AR_dict[names_p6[i]])

for i in range(144,156):
        results_p6.append(AR_dict[names_p6[i]])

for i in range(192,204):
        results_p6.append(AR_dict[names_p6[i]])

results_p6_complete = [(results_p6[i] + results_p6[i+1] + results_p6[i+2]) / 3 for i in range(0, len(results_p6), 3)]

# %%
results_p7 = []
for i in range(12):
        results_p7.append(AR_dict[names_p7[i]])
    
for i in range(48,60):
        results_p7.append(AR_dict[names_p7[i]])

for i in range(96,108):
        results_p7.append(AR_dict[names_p7[i]])

for i in range(144,156):
        results_p7.append(AR_dict[names_p7[i]])

for i in range(192,204):
        results_p7.append(AR_dict[names_p7[i]])

results_p7_complete = [(results_p7[i] + results_p7[i+1] + results_p7[i+2]) / 3 for i in range(0, len(results_p7), 3)]

# %%
results_p8 = []
for i in range(12):
        results_p8.append(AR_dict[names_p8[i]])
    
for i in range(48,60):
        results_p8.append(AR_dict[names_p8[i]])

for i in range(96,108):
        results_p8.append(AR_dict[names_p8[i]])

for i in range(144,156):
        results_p8.append(AR_dict[names_p8[i]])

for i in range(192,204):
        results_p7.append(AR_dict[names_p7[i]])

results_p8_complete = [(results_p8[i] + results_p8[i+1] + results_p8[i+2]) / 3 for i in range(0, len(results_p8), 3)]

# %%
p1 = [np.mean(results_p1_complete[:4]),np.mean(results_p1_complete[4:8]),
     np.mean(results_p1_complete[8:12]), np.mean(results_p1_complete[12:16]),np.mean(results_p1_complete[16:])]

p2 = [np.mean(results_p2_complete[:4]),np.mean(results_p2_complete[4:8]),
     np.mean(results_p2_complete[8:12]), np.mean(results_p2_complete[12:16]),np.mean(results_p2_complete[16:])]

p3 = [np.mean(results_p3_complete[:4]),np.mean(results_p3_complete[4:8]),
     np.mean(results_p3_complete[8:12]), np.mean(results_p3_complete[12:16]),np.mean(results_p3_complete[16:])]

p4 = [np.mean(results_p4_complete[:4]),np.mean(results_p4_complete[4:8]),
     np.mean(results_p4_complete[8:12]), np.mean(results_p4_complete[12:16]),np.mean(results_p4_complete[16:])]

p5 = [np.mean(results_p5_complete[:4]),np.mean(results_p5_complete[4:8]),
     np.mean(results_p5_complete[8:12]), np.mean(results_p5_complete[12:16]),np.mean(results_p5_complete[16:])]

p6 = [np.mean(results_p6_complete[:4]),np.mean(results_p6_complete[4:8]),
     np.mean(results_p6_complete[8:12]), np.mean(results_p6_complete[12:16]),np.mean(results_p6_complete[16:])]

p7 = [np.mean(results_p7_complete[:4]),np.mean(results_p7_complete[4:8]),
     np.mean(results_p7_complete[8:12]), np.mean(results_p7_complete[12:16]),np.mean(results_p6_complete[16:])]

p8 = [np.mean(results_p8_complete[:4]),np.mean(results_p8_complete[4:8]),
     np.mean(results_p8_complete[8:12]), np.mean(results_p8_complete[12:16]),np.mean(results_p6_complete[16:])]

# %%
x = [p1[1]/p1[0],p2[1]/p2[0],p3[1]/p3[0],p4[1]/p4[0],p5[1]/p5[0],p6[1]/p6[0],p7[1]/p7[0],p8[1]/p8[0]]
slope, intercept = np.polyfit(range(1,len(x)+1), x, 1)
y = slope * np.arange(1,len(x)+1) + intercept
plt.scatter(range(1,len(x)+1), x)
plt.plot(np.arange(1,len(x)+1), y, color='red')

# %%
x = [p1[2]/p1[0],p2[2]/p2[0],p3[2]/p3[0],p4[2]/p4[0],p5[2]/p5[0],p6[2]/p6[0],p7[2]/p7[0],p8[2]/p8[0]]
slope, intercept = np.polyfit(range(1,len(x)+1), x, 1)
y = slope * np.arange(1,len(x)+1) + intercept
plt.scatter(range(1,len(x)+1), x)
plt.plot(np.arange(1,len(x)+1), y, color='red')

# %%
x = [p1[3]/p1[0],p2[3]/p2[0],p3[3]/p3[0],p4[3]/p4[0],p5[3]/p5[0],p6[3]/p6[0],p7[3]/p7[0],p8[3]/p8[0]]
slope, intercept = np.polyfit(range(1,len(x)+1), x, 1)
y = slope * np.arange(1,len(x)+1) + intercept
plt.scatter(range(1,len(x)+1), x)
plt.plot(np.arange(1,len(x)+1), y, color='red')

# %%
x = [p1[4]/p1[0],p2[4]/p2[0],p3[4]/p3[0],p4[4]/p4[0],p5[4]/p5[0],p6[4]/p6[0],p7[4]/p7[0],p8[4]/p8[0]]
slope, intercept = np.polyfit(range(1,len(x)+1), x, 1)
y = slope * np.arange(1,len(x)+1) + intercept
plt.scatter(range(1,len(x)+1), x)
plt.plot(np.arange(1,len(x)+1), y, color='red')

# %% [markdown]
# ### Erdös-Renyi graphs

# %% [markdown]
# #### aggregating results

# %%
results_p1 = []
for i in range(12,24):
        results_p1.append(AR_dict[names_p1[i]])
    
for i in range(60,72):
        results_p1.append(AR_dict[names_p1[i]])

for i in range(108,120):
        results_p1.append(AR_dict[names_p1[i]])

for i in range(156,168):
        results_p1.append(AR_dict[names_p1[i]])

for i in range(204,216):
        results_p1.append(AR_dict[names_p1[i]])
    
results_p1_er = [(results_p1[i] + results_p1[i+1] + results_p1[i+2]) / 3 for i in range(0, len(results_p1), 3)]

# %%
results_p2 = []
for i in range(12,24):
        results_p2.append(AR_dict[names_p2[i]])
    
for i in range(60,72):
        results_p2.append(AR_dict[names_p2[i]])

for i in range(108,120):
        results_p2.append(AR_dict[names_p2[i]])

for i in range(156,168):
        results_p2.append(AR_dict[names_p2[i]])

for i in range(204,216):
        results_p1.append(AR_dict[names_p1[i]])

results_p2_er = [(results_p2[i] + results_p2[i+1] + results_p2[i+2]) / 3 for i in range(0, len(results_p2), 3)]

# %%
results_p3 = []
for i in range(12,24):
        results_p3.append(AR_dict[names_p3[i]])
    
for i in range(60,72):
        results_p3.append(AR_dict[names_p3[i]])

for i in range(108,120):
        results_p3.append(AR_dict[names_p3[i]])

for i in range(156,168):
        results_p3.append(AR_dict[names_p3[i]])

for i in range(204,216):
        results_p1.append(AR_dict[names_p1[i]])

results_p3_er = [(results_p3[i] + results_p3[i+1] + results_p3[i+2]) / 3 for i in range(0, len(results_p3), 3)]

# %%
results_p4 = []
for i in range(12,24):
        results_p4.append(AR_dict[names_p4[i]])
    
for i in range(60,72):
        results_p4.append(AR_dict[names_p4[i]])

for i in range(108,120):
        results_p4.append(AR_dict[names_p4[i]])

for i in range(156,168):
        results_p4.append(AR_dict[names_p4[i]])

for i in range(204,216):
        results_p1.append(AR_dict[names_p1[i]])

results_p4_er = [(results_p4[i] + results_p4[i+1] + results_p4[i+2]) / 3 for i in range(0, len(results_p4), 3)]

# %%
results_p5 = []
for i in range(12,24):
        results_p5.append(AR_dict[names_p5[i]])
    
for i in range(60,72):
        results_p5.append(AR_dict[names_p5[i]])

for i in range(108,120):
        results_p5.append(AR_dict[names_p5[i]])

for i in range(156,168):
        results_p5.append(AR_dict[names_p5[i]])

for i in range(204,216):
        results_p1.append(AR_dict[names_p1[i]])

results_p5_er = [(results_p5[i] + results_p5[i+1] + results_p5[i+2]) / 3 for i in range(0, len(results_p5), 3)]

# %%
results_p6 = []
for i in range(12,24):
        results_p6.append(AR_dict[names_p6[i]])
    
for i in range(60,72):
        results_p6.append(AR_dict[names_p6[i]])

for i in range(108,120):
        results_p6.append(AR_dict[names_p6[i]])

for i in range(156,168):
        results_p6.append(AR_dict[names_p6[i]])

for i in range(204,216):
        results_p1.append(AR_dict[names_p1[i]])

results_p6_er = [(results_p6[i] + results_p6[i+1] + results_p6[i+2]) / 3 for i in range(0, len(results_p6), 3)]

# %%
results_p7 = []
for i in range(12,24):
        results_p7.append(AR_dict[names_p7[i]])
    
for i in range(60,72):
        results_p7.append(AR_dict[names_p7[i]])

for i in range(108,120):
        results_p7.append(AR_dict[names_p7[i]])

for i in range(156,168):
        results_p7.append(AR_dict[names_p7[i]])

for i in range(204,216):
        results_p1.append(AR_dict[names_p1[i]])

results_p7_er = [(results_p7[i] + results_p7[i+1] + results_p7[i+2]) / 3 for i in range(0, len(results_p7), 3)]

# %%
results_p8 = []
for i in range(12,24):
        results_p8.append(AR_dict[names_p8[i]])
    
for i in range(60,72):
        results_p8.append(AR_dict[names_p8[i]])

for i in range(108,120):
        results_p8.append(AR_dict[names_p8[i]])

for i in range(156,168):
        results_p8.append(AR_dict[names_p8[i]])

for i in range(204,216):
        results_p1.append(AR_dict[names_p1[i]])

results_p8_er = [(results_p8[i] + results_p8[i+1] + results_p8[i+2]) / 3 for i in range(0, len(results_p8), 3)]

# %%
p1 = [np.mean(results_p1_er[:4]),np.mean(results_p1_er[4:8]),
     np.mean(results_p1_er[8:12]), np.mean(results_p1_er[12:16]),np.mean(results_p1_er[16:])]

p2 = [np.mean(results_p2_er[:4]),np.mean(results_p2_er[4:8]),
     np.mean(results_p2_er[8:12]), np.mean(results_p2_er[12:16]),np.mean(results_p2_er[16:])]

p3 = [np.mean(results_p3_er[:4]),np.mean(results_p3_er[4:8]),
     np.mean(results_p3_er[8:12]), np.mean(results_p3_er[12:16]),np.mean(results_p3_er[16:])]

p4 = [np.mean(results_p4_er[:4]),np.mean(results_p4_er[4:8]),
     np.mean(results_p4_er[8:12]), np.mean(results_p4_er[12:16]),np.mean(results_p4_er[16:])]

p5 = [np.mean(results_p5_er[:4]),np.mean(results_p5_er[4:8]),
     np.mean(results_p5_er[8:12]), np.mean(results_p5_er[12:16]),np.mean(results_p5_er[16:])]

p6 = [np.mean(results_p6_er[:4]),np.mean(results_p6_er[4:8]),
     np.mean(results_p6_er[8:12]), np.mean(results_p6_er[12:16]),np.mean(results_p6_er[16:])]

p7 = [np.mean(results_p7_er[:4]),np.mean(results_p7_er[4:8]),
     np.mean(results_p7_er[8:12]), np.mean(results_p7_er[12:16]),np.mean(results_p6_er[16:])]

p8 = [np.mean(results_p8_er[:4]),np.mean(results_p8_er[4:8]),
     np.mean(results_p8_er[8:12]), np.mean(results_p8_er[12:16]),np.mean(results_p6_er[16:])]

# %%
x = [p1[1]/p1[0],p2[1]/p2[0],p3[1]/p3[0],p4[1]/p4[0],p5[1]/p5[0],p6[1]/p6[0],p7[1]/p7[0],p8[1]/p8[0]]
slope, intercept = np.polyfit(range(1,len(x)+1), x, 1)
y = slope * np.arange(1,len(x)+1) + intercept
plt.scatter(range(1,len(x)+1), x)
plt.plot(np.arange(1,len(x)+1), y, color='red')

# %%
x = [p1[2]/p1[0],p2[2]/p2[0],p3[2]/p3[0],p4[2]/p4[0],p5[2]/p5[0],p6[2]/p6[0],p7[2]/p7[0],p8[2]/p8[0]]
slope, intercept = np.polyfit(range(1,len(x)+1), x, 1)
y = slope * np.arange(1,len(x)+1) + intercept
plt.scatter(range(1,len(x)+1), x)
plt.plot(np.arange(1,len(x)+1), y, color='red')

# %%
x = [p1[3]/p1[0],p2[3]/p2[0],p3[3]/p3[0],p4[3]/p4[0],p5[3]/p5[0],p6[3]/p6[0],p7[3]/p7[0],p8[3]/p8[0]]
slope, intercept = np.polyfit(range(1,len(x)+1), x, 1)
y = slope * np.arange(1,len(x)+1) + intercept
plt.scatter(range(1,len(x)+1), x)
plt.plot(np.arange(1,len(x)+1), y, color='red')

# %% [markdown]
# ### Full binary trees

# %% [markdown]
# #### aggregating results

# %%
results_p1 = []
for i in range(24,36):
        results_p1.append(AR_dict[names_p1[i]])
    
for i in range(72,84):
        results_p1.append(AR_dict[names_p1[i]])

for i in range(120,132):
        results_p1.append(AR_dict[names_p1[i]])

for i in range(168,180):
        results_p1.append(AR_dict[names_p1[i]])

for i in range(216,228):
        results_p1.append(AR_dict[names_p1[i]])

results_p1_bt = [(results_p1[i] + results_p1[i+1] + results_p1[i+2]) / 3 for i in range(0, len(results_p1), 3)]

# %%
results_p2 = []
for i in range(24,36):
        results_p2.append(AR_dict[names_p2[i]])
    
for i in range(72,84):
        results_p2.append(AR_dict[names_p2[i]])

for i in range(120,132):
        results_p2.append(AR_dict[names_p2[i]])

for i in range(168,180):
        results_p2.append(AR_dict[names_p2[i]])

for i in range(216,228):
        results_p1.append(AR_dict[names_p1[i]])

results_p2_bt = [(results_p2[i] + results_p2[i+1] + results_p2[i+2]) / 3 for i in range(0, len(results_p2), 3)]

# %%
results_p3 = []
for i in range(24,36):
        results_p3.append(AR_dict[names_p3[i]])
    
for i in range(72,84):
        results_p3.append(AR_dict[names_p3[i]])

for i in range(120,132):
        results_p3.append(AR_dict[names_p3[i]])

for i in range(168,180):
        results_p3.append(AR_dict[names_p3[i]])

for i in range(216,228):
        results_p1.append(AR_dict[names_p1[i]])

results_p3_bt = [(results_p3[i] + results_p3[i+1] + results_p3[i+2]) / 3 for i in range(0, len(results_p3), 3)]

# %%
results_p4 = []
for i in range(24,36):
        results_p4.append(AR_dict[names_p4[i]])
    
for i in range(72,84):
        results_p4.append(AR_dict[names_p4[i]])

for i in range(120,132):
        results_p4.append(AR_dict[names_p4[i]])

for i in range(168,180):
        results_p4.append(AR_dict[names_p4[i]])

for i in range(216,228):
        results_p1.append(AR_dict[names_p1[i]])

results_p4_bt = [(results_p4[i] + results_p4[i+1] + results_p4[i+2]) / 3 for i in range(0, len(results_p4), 3)]

# %%
results_p5 = []
for i in range(12,24):
        results_p5.append(AR_dict[names_p5[i]])
    
for i in range(60,72):
        results_p5.append(AR_dict[names_p5[i]])

for i in range(132,144):
        results_p5.append(AR_dict[names_p5[i]])

for i in range(180,192):
        results_p5.append(AR_dict[names_p5[i]])

for i in range(216,228):
        results_p1.append(AR_dict[names_p1[i]])

results_p5_bt = [(results_p5[i] + results_p5[i+1] + results_p5[i+2]) / 3 for i in range(0, len(results_p5), 3)]

# %%
results_p6 = []
for i in range(12,24):
        results_p6.append(AR_dict[names_p6[i]])
    
for i in range(60,72):
        results_p6.append(AR_dict[names_p6[i]])

for i in range(132,144):
        results_p6.append(AR_dict[names_p6[i]])

for i in range(180,192):
        results_p6.append(AR_dict[names_p6[i]])

for i in range(216,228):
        results_p1.append(AR_dict[names_p1[i]])

results_p6_bt = [(results_p6[i] + results_p6[i+1] + results_p6[i+2]) / 3 for i in range(0, len(results_p6), 3)]

# %%
results_p7 = []
for i in range(12,24):
        results_p7.append(AR_dict[names_p7[i]])
    
for i in range(60,72):
        results_p7.append(AR_dict[names_p7[i]])

for i in range(132,144):
        results_p7.append(AR_dict[names_p7[i]])

for i in range(180,192):
        results_p7.append(AR_dict[names_p7[i]])

for i in range(216,228):
        results_p1.append(AR_dict[names_p1[i]])

results_p7_bt = [(results_p7[i] + results_p7[i+1] + results_p7[i+2]) / 3 for i in range(0, len(results_p7), 3)]

# %%
results_p8 = []
for i in range(12,24):
        results_p8.append(AR_dict[names_p8[i]])
    
for i in range(60,72):
        results_p8.append(AR_dict[names_p8[i]])

for i in range(132,144):
        results_p8.append(AR_dict[names_p8[i]])

for i in range(180,192):
        results_p8.append(AR_dict[names_p8[i]])

for i in range(216,228):
        results_p1.append(AR_dict[names_p1[i]])

results_p8_bt = [(results_p8[i] + results_p8[i+1] + results_p8[i+2]) / 3 for i in range(0, len(results_p8), 3)]

# %%
p1 = [np.mean(results_p1_bt[:4]),np.mean(results_p1_bt[4:8]),
     np.mean(results_p1_bt[8:12]), np.mean(results_p1_bt[12:16]),np.mean(results_p1_bt[16:])]

p2 = [np.mean(results_p2_bt[:4]),np.mean(results_p2_bt[4:8]),
     np.mean(results_p2_bt[8:12]), np.mean(results_p2_bt[12:16]),np.mean(results_p2_bt[16:])]

p3 = [np.mean(results_p3_bt[:4]),np.mean(results_p3_bt[4:8]),
     np.mean(results_p3_bt[8:12]), np.mean(results_p3_bt[12:16]),np.mean(results_p3_bt[16:])]

p4 = [np.mean(results_p4_bt[:4]),np.mean(results_p4_bt[4:8]),
     np.mean(results_p4_bt[8:12]), np.mean(results_p4_bt[12:16]),np.mean(results_p4_bt[16:])]

p5 = [np.mean(results_p5_bt[:4]),np.mean(results_p5_bt[4:8]),
     np.mean(results_p5_bt[8:12]), np.mean(results_p5_bt[12:16]),np.mean(results_p5_bt[16:])]

p6 = [np.mean(results_p6_bt[:4]),np.mean(results_p6_bt[4:8]),
     np.mean(results_p6_bt[8:12]), np.mean(results_p6_bt[12:16]),np.mean(results_p6_bt[16:])]

p7 = [np.mean(results_p7_bt[:4]),np.mean(results_p7_bt[4:8]),
     np.mean(results_p7_bt[8:12]), np.mean(results_p7_bt[12:16]),np.mean(results_p6_bt[16:])]

p8 = [np.mean(results_p8_bt[:4]),np.mean(results_p8_bt[4:8]),
     np.mean(results_p8_bt[8:12]), np.mean(results_p8_bt[12:16]),np.mean(results_p6_bt[16:])]

# %%
x = [p1[1]/p1[0],p2[1]/p2[0],p3[1]/p3[0],p4[1]/p4[0],p5[1]/p5[0],p6[1]/p6[0],p7[1]/p7[0],p8[1]/p8[0]]
slope, intercept = np.polyfit(range(1,len(x)+1), x, 1)
y = slope * np.arange(1,len(x)+1) + intercept
plt.scatter(range(1,len(x)+1), x)
plt.plot(np.arange(1,len(x)+1), y, color='red')

# %%
x = [p1[2]/p1[0],p2[2]/p2[0],p3[2]/p3[0],p4[2]/p4[0],p5[2]/p5[0],p6[2]/p6[0],p7[2]/p7[0],p8[2]/p8[0]]
slope, intercept = np.polyfit(range(1,len(x)+1), x, 1)
y = slope * np.arange(1,len(x)+1) + intercept
plt.scatter(range(1,len(x)+1), x)
plt.plot(np.arange(1,len(x)+1), y, color='red')

# %%
x = [p1[3]/p1[0],p2[3]/p2[0],p3[3]/p3[0],p4[3]/p4[0],p5[3]/p5[0],p6[3]/p6[0],p7[3]/p7[0],p8[3]/p8[0]]
slope, intercept = np.polyfit(range(1,len(x)+1), x, 1)
y = slope * np.arange(1,len(x)+1) + intercept
plt.scatter(range(1,len(x)+1), x)
plt.plot(np.arange(1,len(x)+1), y, color='red')

# %% [markdown]
# ### Random 3-regular graphs

# %% [markdown]
# #### aggregating results

# %%
results_p1 = []
for i in range(36,48):
        results_p1.append(AR_dict[names_p1[i]])
    
for i in range(84,96):
        results_p1.append(AR_dict[names_p1[i]])

for i in range(132,144):
        results_p1.append(AR_dict[names_p1[i]])

for i in range(180,192):
        results_p1.append(AR_dict[names_p1[i]])

for i in range(228,240):
        results_p1.append(AR_dict[names_p1[i]])

results_p1_r = [(results_p1[i] + results_p1[i+1] + results_p1[i+2]) / 3 for i in range(0, len(results_p1), 3)]

# %%
results_p2 = []
for i in range(36,48):
        results_p2.append(AR_dict[names_p2[i]])
    
for i in range(84,96):
        results_p2.append(AR_dict[names_p2[i]])

for i in range(132,144):
        results_p2.append(AR_dict[names_p2[i]])

for i in range(180,192):
        results_p2.append(AR_dict[names_p2[i]])

for i in range(228,240):
        results_p1.append(AR_dict[names_p1[i]])

results_p2_r = [(results_p2[i] + results_p2[i+1] + results_p2[i+2]) / 3 for i in range(0, len(results_p2), 3)]

# %%
results_p3 = []
for i in range(36,48):
        results_p3.append(AR_dict[names_p3[i]])
    
for i in range(84,96):
        results_p3.append(AR_dict[names_p3[i]])

for i in range(132,144):
        results_p3.append(AR_dict[names_p3[i]])

for i in range(180,192):
        results_p3.append(AR_dict[names_p3[i]])

for i in range(228,240):
        results_p1.append(AR_dict[names_p1[i]])

results_p3_r = [(results_p3[i] + results_p3[i+1] + results_p3[i+2]) / 3 for i in range(0, len(results_p3), 3)]

# %%
results_p4 = []
for i in range(36,48):
        results_p4.append(AR_dict[names_p4[i]])
    
for i in range(84,96):
        results_p4.append(AR_dict[names_p4[i]])

for i in range(132,144):
        results_p4.append(AR_dict[names_p4[i]])

for i in range(180,192):
        results_p4.append(AR_dict[names_p4[i]])

for i in range(228,240):
        results_p1.append(AR_dict[names_p1[i]])

results_p4_r = [(results_p4[i] + results_p4[i+1] + results_p4[i+2]) / 3 for i in range(0, len(results_p4), 3)]

# %%
results_p5 = []
for i in range(36,48):
        results_p5.append(AR_dict[names_p5[i]])
    
for i in range(84,96):
        results_p5.append(AR_dict[names_p5[i]])

for i in range(132,144):
        results_p5.append(AR_dict[names_p5[i]])

for i in range(180,192):
        results_p5.append(AR_dict[names_p5[i]])

for i in range(228,240):
        results_p1.append(AR_dict[names_p1[i]])

results_p5_r = [(results_p5[i] + results_p5[i+1] + results_p5[i+2]) / 3 for i in range(0, len(results_p5), 3)]

# %%
results_p6 = []
for i in range(36,48):
        results_p6.append(AR_dict[names_p6[i]])
    
for i in range(84,96):
        results_p6.append(AR_dict[names_p6[i]])

for i in range(132,144):
        results_p6.append(AR_dict[names_p6[i]])

for i in range(180,192):
        results_p6.append(AR_dict[names_p6[i]])

for i in range(228,240):
        results_p1.append(AR_dict[names_p1[i]])

results_p6_r = [(results_p6[i] + results_p6[i+1] + results_p6[i+2]) / 3 for i in range(0, len(results_p6), 3)]

# %%
results_p7 = []
for i in range(36,48):
        results_p7.append(AR_dict[names_p7[i]])
    
for i in range(84,96):
        results_p7.append(AR_dict[names_p7[i]])

for i in range(132,144):
        results_p7.append(AR_dict[names_p7[i]])

for i in range(180,192):
        results_p7.append(AR_dict[names_p7[i]])

for i in range(228,240):
        results_p1.append(AR_dict[names_p1[i]])

results_p7_r = [(results_p7[i] + results_p7[i+1] + results_p7[i+2]) / 3 for i in range(0, len(results_p7), 3)]

# %%
results_p8 = []
for i in range(36,48):
        results_p8.append(AR_dict[names_p8[i]])
    
for i in range(84,96):
        results_p8.append(AR_dict[names_p8[i]])

for i in range(132,144):
        results_p8.append(AR_dict[names_p8[i]])

for i in range(180,192):
        results_p8.append(AR_dict[names_p8[i]])

for i in range(228,240):
        results_p1.append(AR_dict[names_p1[i]])

results_p8_r = [(results_p8[i] + results_p8[i+1] + results_p8[i+2]) / 3 for i in range(0, len(results_p8), 3)]

# %%
p1 = [np.mean(results_p1_r[:4]),np.mean(results_p1_r[4:8]),
     np.mean(results_p1_r[8:12]), np.mean(results_p1_r[12:16]),np.mean(results_p1_r[16:])]

p2 = [np.mean(results_p2_r[:4]),np.mean(results_p2_r[4:8]),
     np.mean(results_p2_r[8:12]), np.mean(results_p2_r[12:16]),np.mean(results_p2_r[16:])]

p3 = [np.mean(results_p3_r[:4]),np.mean(results_p3_r[4:8]),
     np.mean(results_p3_r[8:12]), np.mean(results_p3_r[12:16]),np.mean(results_p3_r[16:])]

p4 = [np.mean(results_p4_r[:4]),np.mean(results_p4_r[4:8]),
     np.mean(results_p4_r[8:12]), np.mean(results_p4_r[12:16]),np.mean(results_p4_r[16:])]

p5 = [np.mean(results_p5_r[:4]),np.mean(results_p5_r[4:8]),
     np.mean(results_p5_r[8:12]), np.mean(results_p5_r[12:16]),np.mean(results_p5_r[16:])]

p6 = [np.mean(results_p6_r[:4]),np.mean(results_p6_r[4:8]),
     np.mean(results_p6_r[8:12]), np.mean(results_p6_r[12:16]),np.mean(results_p6_r[16:])]

p7 = [np.mean(results_p7_r[:4]),np.mean(results_p7_r[4:8]),
     np.mean(results_p7_r[8:12]), np.mean(results_p7_r[12:16]),np.mean(results_p6_r[16:])]

p8 = [np.mean(results_p8_r[:4]),np.mean(results_p8_r[4:8]),
     np.mean(results_p8_r[8:12]), np.mean(results_p8_r[12:16]),np.mean(results_p6_r[16:])]

# %%
x = [p1[1]/p1[0],p2[1]/p2[0],p3[1]/p3[0],p4[1]/p4[0],p5[1]/p5[0],p6[1]/p6[0],p7[1]/p7[0],p8[1]/p8[0]]
slope, intercept = np.polyfit(range(1,len(x)+1), x, 1)
y = slope * np.arange(1,len(x)+1) + intercept
plt.scatter(range(1,len(x)+1), x)
plt.plot(np.arange(1,len(x)+1), y, color='red')

# %%
x = [p1[2]/p1[0],p2[2]/p2[0],p3[2]/p3[0],p4[2]/p4[0],p5[2]/p5[0],p6[2]/p6[0],p7[2]/p7[0],p8[2]/p8[0]]
slope, intercept = np.polyfit(range(1,len(x)+1), x, 1)
y = slope * np.arange(1,len(x)+1) + intercept
plt.scatter(range(1,len(x)+1), x)
plt.plot(np.arange(1,len(x)+1), y, color='red')

# %%
x = [p1[3]/p1[0],p2[3]/p2[0],p3[3]/p3[0],p4[3]/p4[0],p5[3]/p5[0],p6[3]/p6[0],p7[3]/p7[0],p8[3]/p8[0]]
slope, intercept = np.polyfit(range(1,len(x)+1), x, 1)
y = slope * np.arange(1,len(x)+1) + intercept
plt.scatter(range(1,len(x)+1), x)
plt.plot(np.arange(1,len(x)+1), y, color='red')

# %% [markdown]
# ## Symmetry results analysis (by number of nodes)

# %%
# Gamma
v1_p1 = []
for i in range(4):
    v1_p1.append(results_p1_complete[i])
    v1_p1.append(results_p1_er[i])
    v1_p1.append(results_p1_r[i])
    v1_p1.append(results_p1_bt[i])

# Gamma + one shadow node
v2_p1 = []
for i in range(4,8):
    v2_p1.append(results_p1_complete[i])
    v2_p1.append(results_p1_er[i])
    v2_p1.append(results_p1_r[i])
    v2_p1.append(results_p1_bt[i])

# Gamma + two shadow nodes
v3_p1 = []
for i in range(8,12):
    v3_p1.append(results_p1_complete[i])
    v3_p1.append(results_p1_er[i])
    v3_p1.append(results_p1_r[i])
    v3_p1.append(results_p1_bt[i])

# Gamma + pendent edge
v4_p1 = []
for i in range(12,16):
    v4_p1.append(results_p1_complete[i])
    v4_p1.append(results_p1_er[i])
    v4_p1.append(results_p1_r[i])
    v4_p1.append(results_p1_bt[i])
        
# Gamma - edge
v5_p1 = []
for i in range(16,20):
    v5_p1.append(results_p1_complete[i])
    v5_p1.append(results_p1_er[i])
    v5_p1.append(results_p1_r[i])
    v5_p1.append(results_p1_bt[i])

# %%
AR2_AR1_p1 = [v2_p1[i] / v1_p1[i] for i in range(len(v1_p1))]
AR3_AR1_p1 = [v3_p1[i] / v1_p1[i] for i in range(len(v1_p1))]
AR4_AR1_p1 = [v4_p1[i] / v1_p1[i] for i in range(len(v1_p1))]
AR5_AR1_p1 = [v5_p1[i] / v1_p1[i] for i in range(len(v1_p1))]

plt.plot(AR2_AR1_p1, label="one 'shadow' node")
plt.plot(AR3_AR1_p1, label="two 'shadow' nodes")
plt.plot(AR4_AR1_p1, label="one pendent edge")
plt.plot(AR5_AR1_p1, label="one deleted edge")
plt.ylabel("I'")
plt.legend()
plt.show()

# %%
v1_p8 = []
for i in range(4):
    v1_p8.append(results_p1_complete[i])
    v1_p8.append(results_p1_er[i])
    v1_p8.append(results_p1_r[i])
    v1_p8.append(results_p1_bt[i])


v2_p8 = []
for i in range(4,8):
    v2_p8.append(results_p1_complete[i])
    v2_p8.append(results_p1_er[i])
    v2_p8.append(results_p1_r[i])
    v2_p8.append(results_p1_bt[i])

v3_p8 = []
for i in range(8,12):
    v3_p8.append(results_p1_complete[i])
    v3_p8.append(results_p1_er[i])
    v3_p8.append(results_p1_r[i])
    v3_p8.append(results_p1_bt[i])

v4_p8 = []
for i in range(12,16):
    v4_p8.append(results_p1_complete[i])
    v4_p8.append(results_p1_er[i])
    v4_p8.append(results_p1_r[i])
    v4_p8.append(results_p1_bt[i])
        

v5_p8 = []
for i in range(16,20):
    v5_p8.append(results_p1_complete[i])
    v5_p8.append(results_p1_er[i])
    v5_p8.append(results_p1_r[i])
    v5_p8.append(results_p1_bt[i])

# %%
AR2_AR1_p8 = [v2_p8[i] / v1_p8[i] for i in range(len(v1_p1))]
AR3_AR1_p8 = [v3_p8[i] / v1_p8[i] for i in range(len(v1_p1))]
AR4_AR1_p8 = [v4_p8[i] / v1_p8[i] for i in range(len(v1_p1))]
AR5_AR1_p8 = [v5_p8[i] / v1_p8[i] for i in range(len(v1_p1))]

plt.plot(AR2_AR1_p8, label="one 'shadow' node")
plt.plot(AR3_AR1_p8, label="two 'shadow' nodes")
plt.plot(AR4_AR1_p8, label="one pendent edge")
plt.plot(AR5_AR1_p8, label="one deleted edge")
plt.ylabel("I'")
plt.legend()
plt.show()

# %% [markdown]
# ## Spectum

# %%
with open("results/spectral_radii", 'rb') as file:
        sigma = pickle.load(file)
sigma
# Out:
# [2.9999999999999996,
#  4.999999999999999,
#  6.9999999999999964,
#  8.999999999999998,
#  1.4142135623730951,
#  2.7964374026209544,
#  3.0535605220140862,
#  4.689511329550138,
#  1.6180339887498945,
#  1.9021130325903044,
#  2.0420789618979054,
#  2.154341309122883,
#  2.9999999999999996,
#  2.999999999999999,
#  3.0,
#  2.9999999999999964]

# %%
with open("results/spectral_radii_deleted", 'rb') as file:
        sigma_deleted = pickle.load(file)
sigma_deleted = [value for value in sigma_deleted.values()]
sigma_deleted
# Out:
# [2.561552812808831,
#  4.701562118716425,
#  6.772001872658773,
#  8.815072906367332,
#  1.0,
#  2.5990723964293765,
#  3.0143256523762765,
#  4.640310102930605,
#  1.4142135623730951,
#  1.8477590650225726,
#  1.9999999999999984,
#  2.119165782887462,
#  2.561552812808831,
#  2.7410819813819383,
#  2.8234905657004776,
#  2.8608058531117067]

# %%
with open("results/spectral_radii_pendent", 'rb') as file:
        sigma_pendent = pickle.load(file)
sigma_pendent
# Out:
# [3.086130197651496,
#  5.03404183580349,
#  7.018092436973712,
#  9.011209116293989,
#  1.6180339887498956,
#  2.840212473565013,
#  3.12345548474823,
#  4.718879652586869,
#  1.8477590650225726,
#  2.1010029896154574,
#  2.1678625759663186,
#  2.1692364387746705,
#  3.086130197651496,
#  3.059445635599562,
#  3.0455518769009897,
#  3.037048281088164]

# %%
with open("results/spectral_radii_shadow1", 'rb') as file:
        sigma_shadow1 = pickle.load(file)
sigma_shadow1
# Out:
# [2.9999999999999996,
#  4.999999999999999,
#  6.9999999999999964,
#  8.999999999999998,
#  1.4142135623730951,
#  2.7964374026209544,
#  3.0535605220140862,
#  4.689511329550138,
#  1.6180339887498945,
#  1.9021130325903044,
#  2.0420789618979054,
#  2.154341309122883,
#  2.9999999999999996,
#  2.999999999999999,
#  3.0,
#  2.9999999999999964]

# %%
with open("results/spectral_radii_shadow2", 'rb') as file:
        sigma_shadow2 = pickle.load(file)
sigma_shadow2
# Out:
# [2.9999999999999996,
#  4.999999999999999,
#  6.9999999999999964,
#  8.999999999999998,
#  1.4142135623730951,
#  2.7964374026209544,
#  3.0535605220140862,
#  4.689511329550138,
#  1.6180339887498945,
#  1.9021130325903044,
#  2.0420789618979054,
#  2.154341309122883,
#  2.9999999999999996,
#  2.999999999999999,
#  3.0,
#  2.9999999999999964]

# %%
with open("results/spectral_metric_unperturbed", 'rb') as file:
        rho = pickle.load(file)
rho =[value[0] for value in rho.values()]
rho
# Out:
# [1.0000000000000002,
#  1.0000000000000002,
#  1.0000000000000004,
#  1.0000000000000002,
#  0.7071067811865475,
#  0.7151956979711059,
#  0.6549730996262775,
#  0.8529673390049615,
#  0.618033988749895,
#  0.5257311121191344,
#  0.48969702869403314,
#  0.46417900254028893,
#  1.0000000000000002,
#  1.0000000000000002,
#  1.0,
#  1.000000000000001]

# %%
with open("results/spectral_metric_shadow1", 'rb') as file:
        rho_shadow1 = pickle.load(file)
rho_shadow1 = [value[0] for value in rho_shadow1.values()]
rho_shadow1
# Out:
# [0.6666666666666667,
#  0.8000000000000002,
#  0.8571428571428575,
#  0.8888888888888891,
#  0.0,
#  0.7151956979711059,
#  0.6549730996262775,
#  0.8529673390049615,
#  0.618033988749895,
#  0.5257311121191344,
#  0.48969702869403314,
#  0.46417900254028893,
#  0.6666666666666667,
#  0.6666666666666669,
#  0.6666666666666666,
#  0.6666666666666674]

# %%
with open("results/spectral_metric_shadow2", 'rb') as file:
        rho_shadow2 = pickle.load(file)
rho_shadow2 = [value[0] for value in rho_shadow2.values()]
rho_shadow2
# Out:
# [0.6666666666666667,
#  0.6000000000000001,
#  0.7142857142857146,
#  0.7777777777777779,
#  0.0,
#  0.7151956979711059,
#  0.32748654981313874,
#  0.6397255042537211,
#  0.618033988749895,
#  0.5257311121191344,
#  0.48969702869403314,
#  0.46417900254028893,
#  0.6666666666666667,
#  0.6666666666666669,
#  0.6666666666666666,
#  0.6666666666666674]

# %%
with open("results/spectral_metric_pendent", 'rb') as file:
        rho_pendent = pickle.load(file)
rho_pendent = [value[0] for value in rho_pendent.values()]
rho_pendent
# Out:
# [0.6480607984465379,
#  0.7945901385941809,
#  0.8549331679346296,
#  0.8877831927720411,
#  0.6180339887498946,
#  0.7041726696910162,
#  0.6403164731387913,
#  0.847658828893256,
#  0.5411961001461972,
#  0.4759631494779682,
#  0.4612838521621938,
#  0.4609917029445009,
#  0.6480607984465379,
#  0.6537132010871827,
#  0.6566954302006853,
#  0.6585341472686127]

# %%
with open("results/spectral_metric_deleted", 'rb') as file:
        rho_deleted = pickle.load(file)
rho_deleted = [value[0] for value in rho_deleted.values()]
rho_deleted
# Out:
# [0.7807764064044148,
#  0.850781059358212,
#  0.8860009363293818,
#  0.9075364531836616,
#  0.0,
#  0.7695053061036752,
#  0.6634983179151014,
#  0.8620113551190869,
#  0.7071067811865475,
#  0.5411961001461972,
#  0.5000000000000004,
#  0.4718837988396799,
#  0.7807764064044148,
#  0.7296388847850819,
#  0.7083430787040089,
#  0.6991037150684638]

# %%
plt.plot(range(16), list(rho)[:16], "grey", label = "no perturbation")
plt.plot(range(16), list(rho_shadow1)[:16], ":", label="'shadow' nodes")
plt.plot(range(16), list(rho_shadow2)[:16], ":", label="'shadow' nodes")
plt.plot(range(16),list(rho_pendent)[:16],":", label="pendent edges")
plt.plot(range(16),list(rho_deleted)[:16],":", label = "deleted edges")
plt.legend()
plt.show()

# %% [markdown]
# ## Aut(G)

# %%
with open("results/aut_G", 'rb') as file:
        Aut_ = pickle.load(file)
Aut = Aut_[0]
Aut
# Out:
# [24, 720, 40320, 3628800, 2, 2, 1, 1, 2, 2, 2, 4, 24, 12, 12, 20]

# %%
Aut_s1 = [24, 720, 40320, 3628800, 4, 2, 2, 1, 2, 2, 2, 4, 24, 12, 12, 20]
Aut_s2 = [48, 1440, 80640, 7257600, 12, 4, 6, 2, 4, 4, 4, 8, 48, 24, 24, 40]
Aut_p = [6, 120, 5040, 362880, 4, 1, 1, 1, 2, 6, 2, 12, 6, 2, 4, 2]
Aut_d = [4, 48, 1440, 80640, 4, int(np.mean([4, 1, 1, 4, 6, 1, 1, 4])), int(np.mean([2, 2, 2, 1, 2, 2, 1, 1, 4])), 1, 
         int(np.mean([8,2,2])), int(np.mean([8, 12, 2, 2, 2])), int(np.mean([12, 4, 4, 2, 1, 1, 8])), 
         int(np.mean([12, 4, 4, 16, 2, 2, 4, 4, 4])), 4, int(np.mean([2, 4, 2, 2, 4, 4, 2, 2, 2])), 
         int(np.mean([2, 2, 4, 2, 2, 4, 4, 4, 2, 4, 2, 4])), int(np.mean([2, 2, 4, 4, 2, 4, 2, 2, 4, 2, 2, 2, 2, 4, 2]))]

# %%
plt.plot(range(16), Aut, ".", color="red", label="No perturbation")
plt.plot(range(16), Aut_s1, label="one 'shadow' node")
plt.plot(range(16), Aut_s2, label="two 'shadow' nodes")
plt.plot(range(16), Aut_p, label="one pendent edge")
plt.plot(range(16), Aut_d, color="grey", label="one deleted edge")
plt.legend()
plt.show()
